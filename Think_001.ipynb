# %%
'''
ВХОД:
Основы ввода-вывода методами input()-print(). Небольшой экспромт. 

'''

bill = 0 # Так...
x = 0 # ... и так делать не обязательно, но желательно. Хороший тон.

x = input() # Тут и говорить нечего Запросили-Поместили в переменную x.

print("Принято: ", x, ".") # Вывели через метод print(), строку-константу, от переменной-значения отделили запятой(-ыми).
print("Принято: " + x + ".") # ID=001. Чтобы были только заложенные нами пробелы запятые заменим на '+'. Однако это превратит значение переменной "x" в строковый тип. Хотя мы можем привести ее обратно в числовой , см. строку с ID003.
print("Принято: ", x, ".", sep = " ") # Чтобы были только заложенные нами пробелы запятые заменим на '+'.

print("У вас не хватает еще: ", x, ".", sep = "")
y = input("Пополните сколько есть возможность: ")

#bill = x + y # ID=002.
bill = int(x) + int(y) # ID=003.

print("ОК. На вашем счету: ", bill)
print("Что-то пошло не так, сервисный код продиктуйте.")

# ВЫХОД:
# Повторить правила комментирования и документирования. Форматирование строк. Структура программы (def main(): и прочее).
# Несколько задач из задачника. Удаление коммитов из удаленного репозитория (+Ветвление). Работа с файлами в Python. Классы.
